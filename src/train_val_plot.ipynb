# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from statsmodels.nonparametric.kernel_regression import KernelReg

# %%
def plot(type_='train'):
    models = ['ALBERT', 'ELECTRA', 'lr', 'RoBERTa', 'XLNet']

    for model in models:
        file = f'plots/{type_}/{model.lower() + ".csv"}'
        
        if model == 'lr':
            model = 'Ensemble'
        plot_krr(file, label=model)
    
    plt.legend(loc='upper right') 
    plt.show()
plot('train')

# %%
plot('val')
